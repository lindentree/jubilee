# %%
import pandas as pd
import numpy as np
import os
import re

# %%
data = {'artist':[], 'song_name': [], 'file_name': [], 'lyrics': []}

loc = os.listdir('lyrics')
for artist in loc:
    if artist != '.DS_Store':
        for file in os.listdir(f'lyrics/{artist}'):
            if file[0] != '.':
                song_name = file.replace('.txt', '').replace('_', ' ').title()
                data['artist'].append(artist)
                data['song_name'].append(song_name)
                data['file_name'].append(file)
                with open(f'lyrics/{artist}/{file}', 'r') as f:
                    lyrics = f.read()
                data['lyrics'].append(lyrics.replace('\n', ' '))
            
data = pd.DataFrame.from_dict(data)
print(f'Record Count: {len(data)}')
data.head()
# Out:
# Record Count: 2116
#         artist            song_name                file_name  \
# 0  Gary Wright        Love Is Alive        love_is_alive.txt
# 1        LMFAO    Party Rock Anthem    party_rock_anthem.txt
# 2    Metallica                2 X 4                2_x_4.txt
# 3    Metallica      Prince Charming      prince_charming.txt
# 4    Metallica  Now That We'Re Dead  now_that_we're_dead.txt
#
#                                               lyrics
# 0  Well, I think it's time to get ready To realiz...
# 1  Party rock Let's go!  Party rock is in the hou...
# 2  I’m gonna make you, shake you, take you I’m go...
# 3  There’s a black cloud overhead That’s me And t...
# 4  When darkness falls May it be That we should s...

# %% [markdown]
# ### Expand Contractions

# %%
from contractions import CONTRACTION_MAP

def expand_contractions(text, contraction_mapping=CONTRACTION_MAP):
    
    # Cxpand contractions into individual words using pre-defined list of contractions.
    contractions_pattern = re.compile('({})'.format('|'.join(contraction_mapping.keys())), 
                                      flags=re.IGNORECASE|re.DOTALL)
    def expand_match(contraction):
        # Find words in text that match with contraction map, and return expanded text
        match = contraction.group(0)
        first_char = match[0]
        expanded_contraction = contraction_mapping.get(match)\
                                if contraction_mapping.get(match)\
                                else contraction_mapping.get(match.lower())                       
        expanded_contraction = first_char+expanded_contraction[1:]
        return expanded_contraction
        
    expanded_text = contractions_pattern.sub(expand_match, text)
    expanded_text = re.sub("'", "", expanded_text)
    return expanded_text

# %% [markdown]
# ### Remove Special Characters

# %%
def remove_special_characters(text, remove_digits=False):
    # Remove special characters from text
    pattern = r'[^a-zA-z0-9\s]' if not remove_digits else r'[^a-zA-z\s]'
    text = re.sub(pattern, ' ', text)
    return text

# %% [markdown]
# ### Lemmatize Text

# %%
import spacy
nlp = spacy.load('en_core_web_md', parse=True, tag=True, entity=True)

def lemmatize_text(text):
    # Get base form for word variants (i.e. running ==> run, cats ==> cat, etc.)
    text = nlp(text)
    text = ' '.join([word.lemma_ if word.lemma_ != '-PRON-' else word.text for word in text])
    return text

# %% [markdown]
# ### Remove Stopwords and Tokenize

# %%
import nltk
from nltk.tokenize.toktok import ToktokTokenizer

tokenizer = ToktokTokenizer()

# Remove words 'no' and 'not' from stopword list as these may change meaning of words/phrases
stopword_list = nltk.corpus.stopwords.words('english')
for word in ['no', 'not', 'he', 'she', 'his', 'her', 'hers']:
    stopword_list.remove(word)

# Add characters not captured in special character removal to stop list
stopword_list += ['[', ']', "\\"]                     

def remove_stopwords(text, is_lower_case=False):
    tokens = tokenizer.tokenize(text)
    tokens = [token.strip() for token in tokens]
    if is_lower_case:
        filtered_tokens = [token for token in tokens if token not in stopword_list]
    else:
        filtered_tokens = [token for token in tokens if token.lower() not in stopword_list]
    filtered_text = ' '.join(filtered_tokens)    
    return filtered_text

# %% [markdown]
# ### Apply All Cleaning Functions

# %%
import unicodedata

def clean_text(cust_text):
    # Remove accent characters => Expand Contractions => Remove special characters => Lammatize Text => Remove Stop Words
    no_accent_chars = unicodedata.normalize('NFKD', cust_text).encode('ascii', 'ignore').decode('utf-8', 'ignore')
    expanded_text = expand_contractions(no_accent_chars)
    no_special_chars = remove_special_characters(expanded_text, remove_digits=False)
    lem_text = lemmatize_text(no_special_chars)
    filtered_text = remove_stopwords(lem_text)

    # Make all text lowercase
    lowercase_text = filtered_text.lower()

    # Split text into list of words
    words = lowercase_text.split()
    return words

# %%
data['clean_lyrics'] = data.lyrics.apply(lambda x: clean_text(x))
data.head()
# Out:
#         artist            song_name                file_name  \
# 0  Gary Wright        Love Is Alive        love_is_alive.txt
# 1        LMFAO    Party Rock Anthem    party_rock_anthem.txt
# 2    Metallica                2 X 4                2_x_4.txt
# 3    Metallica      Prince Charming      prince_charming.txt
# 4    Metallica  Now That We'Re Dead  now_that_we're_dead.txt
#
#                                               lyrics  \
# 0  Well, I think it's time to get ready To realiz...
# 1  Party rock Let's go!  Party rock is in the hou...
# 2  I’m gonna make you, shake you, take you I’m go...
# 3  There’s a black cloud overhead That’s me And t...
# 4  When darkness falls May it be That we should s...
#
#                                         clean_lyrics
# 0  [well, think, time, get, ready, realize, find,...
# 1  [party, rock, let, us, go, party, rock, house,...
# 2  [go, make, shake, take, go, one, break, put, s...
# 3  [black, cloud, overhead, poison, ivy, choke, t...
# 4  [darkness, fall, may, see, light, reaper, call...

# %%
data.to_csv('recommendation_resources/preprocessed_lyrics.csv')

# %%
rec_df = pd.read_csv('recommendation_resources/preprocessed_lyrics.csv', index_col=0, usecols=list(range(4)))
rec_df.head()
# Out:
#         artist            song_name                file_name
# 0  Gary Wright        Love Is Alive        love_is_alive.txt
# 1        LMFAO    Party Rock Anthem    party_rock_anthem.txt
# 2    Metallica                2 X 4                2_x_4.txt
# 3    Metallica      Prince Charming      prince_charming.txt
# 4    Metallica  Now That We'Re Dead  now_that_we're_dead.txt

# %%
all_recs = []

for i in rec_df.index:
    rec_ids = [np.random.randint(0, len(data)) for i in range(5)]
    recs = {}
    for j in rec_ids:
        recs[rec_df.artist[j]]={rec_df.song_name[j]:rec_df.file_name[j]}
#         recs.append(rec)
    all_recs.append(recs)

rec_df['recommendations'] = all_recs
rec_df.head()
# Out:
#         artist            song_name                file_name  \
# 0  Gary Wright        Love Is Alive        love_is_alive.txt
# 1        LMFAO    Party Rock Anthem    party_rock_anthem.txt
# 2    Metallica                2 X 4                2_x_4.txt
# 3    Metallica      Prince Charming      prince_charming.txt
# 4    Metallica  Now That We'Re Dead  now_that_we're_dead.txt
#
#                                      recommendations
# 0  {'Temptations': {'Love On My Mind Tonight': 'l...
# 1  {'Frank Sinatra': {'My Funny Valentine': 'my_f...
# 2  {'Little Richard': {'Tutti Frutti': 'tutti_fru...
# 3  {'Frank Sinatra': {'I'Ve Got You Under My Skin...
# 4  {'Hank Williams': {'I Won'T Be Home No More': ...

# %%
import json

recs = {}
for artist in rec_df.artist.unique():
    recs[artist] = {}

for i in rec_df.index:
    song_info = {
        'file_name':rec_df.file_name[i],
        'recommendations':rec_df.recommendations[i],
    }
    recs[rec_df.artist[i]][rec_df.song_name[i]]=song_info

with open("recommendations.json", "w") as outfile:  
    json.dump(recs, outfile)

recs
# Out:
# {'Gary Wright': {'Love Is Alive': {'file_name': 'love_is_alive.txt',
#    'recommendations': {'Temptations': {'Love On My Mind Tonight': 'love_on_my_mind_tonight.txt'},
#     'Beatles': {'You Like Me Too Much': 'you_like_me_too_much.txt'},
#     'Simon & Garfunkel': {'Save The Life Of My Child': 'save_the_life_of_my_child.txt'},
#     'Frank Sinatra': {'Taking A Chance On Love': 'taking_a_chance_on_love.txt'},
#     'Monkees': {"I'M A Believer": "i'm_a_believer.txt"}}}},
#  'LMFAO': {'Party Rock Anthem': {'file_name': 'party_rock_anthem.txt',
#    'recommendations': {'Frank Sinatra': {'My Funny Valentine': 'my_funny_valentine.txt'},
#     'Ray Charles': {'After My Laughter Came Tears': 'after_my_laughter_came_tears.txt'},
#     'Jerry Lee Lewis': {'Help Me Make It Through The Night': 'help_me_make_it_through_the_night.txt'},
#     'Little Richard': {'Baby Face': 'baby_face.txt'},
#     'Who': {'Blue, Red And Grey': 'blue,_red_and_grey.txt'}}}},
#  'Metallica': {'2 X 4': {'file_name': '2_x_4.txt',
#    'recommendations': {'Little Richard': {'Tutti Frutti': 'tutti_frutti.txt'},
#     'Beach Boys': {'Noble Surfer': 'noble_surfer.txt'},
#     'Ray Charles': {'Mary Ann': 'mary_ann.txt'},
#     'Def Leppard': {"You Got Me Runnin'": "you_got_me_runnin'.txt"},
#     'Prince': {'Thieves In The Temple': 'thieves_in_the_temple.txt'}}},
#   'Prince Charming': {'file_name': 'prince_charming.txt',
#    'recommendations': {'Frank Sinatra': {"I'Ve Got You Under My Skin": "i've_got_you_under_my_skin.txt"},
#     'Bo Diddley': {'Before You Accuse Me': 'before_you_accuse_me.txt'},
#     'All-4-One': {'I Swear': 'i_swear.txt'},
#     'Usher': {'Burn': 'burn.txt'},
#     'Little Richard': {'Lucille': 'lucille.txt'}}},
#   "Now That We'Re Dead": {'file_name': "now_that_we're_dead.txt",
#    'recommendations': {'Hank Williams': {"I Won'T Be Home No More": "i_won't_be_home_no_more.txt"},
#     'Willie Nelson': {"The Party'S Over": "the_party's_over.txt"},
#     'Ray Charles': {"Feelin' Sad": "feelin'_sad.txt"},
#     'Anthrax': {'Grunt And Click(2001 Reissue Bonus Track)': 'grunt_and_click(2001_reissue_bonus_track).txt'},
#     'Prince': {'When Doves Cry': 'when_doves_cry.txt'}}},
#   'Creeping Death': {'file_name': 'creeping_death.txt',
#    'recommendations': {'Willie Nelson': {"(How Will I Know) I'M Falling In Love Again": "(how_will_i_know)_i'm_falling_in_love_again.txt"},
#     'Aretha Franklin': {'Until The Real Thing Comes Along': 'until_the_real_thing_comes_along.txt'},
#     'Run-DMC': {'Peter Piper': 'peter_piper.txt'},
#     'Queen': {'Play The Game': 'play_the_game.txt'},
#     'Tom Jones': {"I'Ll Never Fall In Love Again": "i'll_never_fall_in_love_again.txt"}}},
#   'Halo On Fire': {'file_name': 'halo_on_fire.txt',
#    'recommendations': {'Maroon 5': {'Sugar': 'sugar.txt'},
#     'Rolling Stones': {'What A Shame': 'what_a_shame.txt'},
#     'Ray Charles': {"That'S Enough": "that's_enough.txt"},
#     'Police': {'Every Breath You Take': 'every_breath_you_take.txt'},
#     'Lil Nas X': {'Old Town Road': 'old_town_road.txt'}}},
#   'Crash Course In Brain Surgery': {'file_name': 'crash_course_in_brain_surgery.txt',
#    'recommendations': {'Bo Diddley': {'Cheyenne': 'cheyenne.txt'},
#     'Melanie': {'Brand New Key': 'brand_new_key.txt'},
#     'Metallica': {'Iced Honey': 'iced_honey.txt'},
#     'Prince': {'Forever In My Life': 'forever_in_my_life.txt'},
#     'Hank Williams': {'A Home In Heaven': 'a_home_in_heaven.txt'}}},
#   'Poor Twisted Me': {'file_name': 'poor_twisted_me.txt',
#    'recommendations': {'ACDC': {'Playing With Girls': 'playing_with_girls.txt'},
#     'Pitbull': {'Give Me Everything': 'give_me_everything.txt'},
#     'Radiohead': {'The National Anthem': 'the_national_anthem.txt'},
#     'Mark Ronson': {'Uptown Funk': 'uptown_funk.txt'},
#     'Puff Daddy': {"Can'T Nobody Hold Me Down": "can't_nobody_hold_me_down.txt"}}},
#   'The Wait': {'file_name': 'the_wait.txt',
#    'recommendations': {'Blondie': {'The Hunter Gets Captured By The Game': 'the_hunter_gets_captured_by_the_game.txt'},
#     'Billy Joel': {'Los Angelenos': 'los_angelenos.txt'},
#     'Amy Winehouse': {'To Know Him Is To Love Him(Deluxe Edition Bonus Track)': 'to_know_him_is_to_love_him(deluxe_edition_bonus_track).txt'},
#     'KISS': {'Only You': 'only_you.txt'},
#     'Def Leppard': {"You Got Me Runnin'": "you_got_me_runnin'.txt"}}},
#   'All Within My Hands': {'file_name': 'all_within_my_hands.txt',
#    'recommendations': {'Police': {"It'S Alright For You": "it's_alright_for_you.txt"},
#     'Association': {'Cherish': 'cherish.txt'},
#     'Clash': {'Somebody Got Murdered': 'somebody_got_murdered.txt'},
#     'Velvet Underground': {'Head Held High': 'head_held_high.txt'},
#     'Supremes': {'I Want A Guy': 'i_want_a_guy.txt'}}},
#   'That Was Just Your Life': {'file_name': 'that_was_just_your_life.txt',
#    'recommendations': {'Van Halen': {'Feels So Good': 'feels_so_good.txt'},
#     'Bo Diddley': {"I'M All Right": "i'm_all_right.txt"},
#     'Anthrax': {'Deathrider': 'deathrider.txt'},
#     'Led Zeppelin': {'Kashmir': 'kashmir.txt'},
#     'Sam Cooke': {'The Song Is Ended': 'the_song_is_ended.txt'}}},
#   'The Small Hours': {'file_name': 'the_small_hours.txt',
#    'recommendations': {'Ray Charles': {'Goody, Goody': 'goody,_goody.txt'},
#     'Elvis Costello': {'Hoover Factory': 'hoover_factory.txt'},
#     'Little Richard': {'By The Light Of The Silvery Moon': 'by_the_light_of_the_silvery_moon.txt'},
#     'Beach Boys': {'Barbara Ann': 'barbara_ann.txt'}}},
#   'Whiskey In The Jar': {'file_name': 'whiskey_in_the_jar.txt',
#    'recommendations': {'Bo Diddley': {'Back Home': 'back_home.txt'},
#     'Mary Wells': {'My Guy': 'my_guy.txt'},
#     'Led Zeppelin': {'Four Sticks': 'four_sticks.txt'},
#     'Little Richard': {'It Takes Everything To Serve The Lord': 'it_takes_everything_to_serve_the_lord.txt'},
#     'Smokey Robinson & The Miracles': {'Baby Baby': 'baby_baby.txt'}}},
#   'Brandenburg Gate': {'file_name': 'brandenburg_gate.txt',
#    'recommendations': {'James Brown': {'Begging, Begging': 'begging,_begging.txt'},
#     'Cher': {'Believe': 'believe.txt'},
#     'Hall & Oates': {'Friday Let Me Down': 'friday_let_me_down.txt'},
#     'Otis Redding': {"(Sittin' On) The Dock Of The Bay": "(sittin'_on)_the_dock_of_the_bay.txt"}}},
#   'Dyers Eve': {'file_name': 'dyers_eve.txt',
#    'recommendations': {'Alice Cooper': {'How You Gonna See Me Now': 'how_you_gonna_see_me_now.txt'},
#     'Chuck Berry': {'Let It Rock': 'let_it_rock.txt'},
#     'Hank Williams': {'My Son Calls Another Man Daddy': 'my_son_calls_another_man_daddy.txt'},
#     'Rolling Stones': {'Honky Tonk Women': 'honky_tonk_women.txt'},
#     'Metallica': {'Brandenburg Gate': 'brandenburg_gate.txt'}}},
#   'Cheat On Me': {'file_name': 'cheat_on_me.txt',
#    'recommendations': {'Radiohead': {'The National Anthem': 'the_national_anthem.txt'},
#     'Chuck Berry': {'Dutchman': 'dutchman.txt'},
#     'Madonna': {'Beautiful Killer(Deluxe Edition Bonus Track)': 'beautiful_killer(deluxe_edition_bonus_track).txt'},
#     'Beach Boys': {'California Girls': 'california_girls.txt'},
#     'Ray Charles': {"Don'T Let The Sun Catch You Cryin'": "don't_let_the_sun_catch_you_cryin'.txt"}}},
#   'Iced Honey': {'file_name': 'iced_honey.txt',
#    'recommendations': {'Ray Charles': {'Have You Met Miss Jones?': 'have_you_met_miss_jones?.txt'},
#     'Clash': {'The Crooked Beat': 'the_crooked_beat.txt'},
#     'Everly Brothers': {'She Never Smiles Anymore': 'she_never_smiles_anymore.txt'},
#     'Eurythmics': {'In This Town': 'in_this_town.txt'}}},
#   'Cure': {'file_name': 'cure.txt',
#    'recommendations': {'Public Enemy': {'Get It In': 'get_it_in.txt'},
#     'Nirvana': {'Smells Like Teen Spirit': 'smells_like_teen_spirit.txt'},
#     'Hank Williams': {'Please Make Up Your Mind': 'please_make_up_your_mind.txt'},
#     'Bo Diddley': {'Cops & Robbers': 'cops_&_robbers.txt'},
#     'Jimi Hendrix': {'Drifting': 'drifting.txt'}}},
#   'The Outlaw Torn': {'file_name': 'the_outlaw_torn.txt',
#    'recommendations': {'Aerosmith': {"Adam'S Apple": "adam's_apple.txt"},
#     'Jimi Hendrix': {'Voodoo Child (Slight Return)': 'voodoo_child_(slight_return).txt'},
#     'Joe': {'I Wanna Know': 'i_wanna_know.txt'},
#     'Velvet Underground': {'Cool It Down': 'cool_it_down.txt'},
#     'Simon & Garfunkel': {'Barbriallen(From "The Columbia Studio Recordings (1964–1970)" Box Set)': 'barbriallen(from_"the_columbia_studio_recordings_(1964–1970)"_box_set).txt'}}},
#   'The House Jack Built': {'file_name': 'the_house_jack_built.txt',
#    'recommendations': {'Public Enemy': {'Night Of The Living Basheads': 'night_of_the_living_basheads.txt'},
#     'Elvis Costello': {'Hoover Factory': 'hoover_factory.txt'},
#     'Taylor Swift': {'Love Story': 'love_story.txt'},
#     'Sir Mix-a-Lot': {'Baby Got Back': 'baby_got_back.txt'},
#     'Jimi Hendrix': {'Remember': 'remember.txt'}}}},
#  'Debby Boone': {'You Light Up My Life': {'file_name': 'you_light_up_my_life.txt',
#    'recommendations': {'Willie Nelson': {'Always On My Mind': 'always_on_my_mind.txt'},
#     'Jay-Z': {'Hova Song (Outro)': 'hova_song_(outro).txt'},
#     'Hank Williams': {'The Blues Come Around': 'the_blues_come_around.txt'},
#     'Queen': {'Teo Torriate (Let Us Cling Together)': 'teo_torriate_(let_us_cling_together).txt'},
#     'Supremes': {"A Hard Day'S Night": "a_hard_day's_night.txt"}}}},
#  'Leona Lewis': {'Bleeding Love': {'file_name': 'bleeding_love.txt',
#    'recommendations': {'NWA': {'The Dayz Of Wayback': 'the_dayz_of_wayback.txt'},
#     'Ray Charles': {'Mess Around': 'mess_around.txt'},
#     'Marvin Gaye': {'Why Did I Choose You?': 'why_did_i_choose_you?.txt'},
#     'Led Zeppelin': {'Custard Pie': 'custard_pie.txt'}}}},
#  'Kool & the Gang': {'Celebration': {'file_name': 'celebration.txt',
#    'recommendations': {'ACDC': {'The Jack': 'the_jack.txt'},
#     'Prince': {'Daddy Pop': 'daddy_pop.txt'},
#     'Ray Charles': {"Tell Me You'Ll Wait For Me": "tell_me_you'll_wait_for_me.txt"},
#     'Billy Joel': {'Everybody Has A Dream': 'everybody_has_a_dream.txt'},
#     'Van Morrison': {'Streets Of Arklow': 'streets_of_arklow.txt'}}}},
#  'Little Eva': {'The Loco-Motion': {'file_name': 'the_loco-motion.txt',
#    'recommendations': {'Velvet Underground': {'Coyote': 'coyote.txt'},
#     'Wilson Phillips': {'Hold On': 'hold_on.txt'},
#     'Queen': {'My Babe Does Me': 'my_babe_does_me.txt'},
#     'KISS': {'Little Caesar': 'little_caesar.txt'},
#     'Ray Charles': {'Over The Rainbow': 'over_the_rainbow.txt'}}}},
#  'Justin Bieber': {'Sorry': {'file_name': 'sorry.txt',
#    'recommendations': {'Ray Charles': {"Ray'S Blues": "ray's_blues.txt"},
#     'Hank Williams': {"They'Ll Never Take Her Love From Me": "they'll_never_take_her_love_from_me.txt"},
#     'Genesis': {'Follow You Follow Me': 'follow_you_follow_me.txt'},
#     'ACDC': {'Rising Power': 'rising_power.txt'}}},
#   'Love Yourself': {'file_name': 'love_yourself.txt',
#    'recommendations': {'Sam Cooke': {'Wonderful World': 'wonderful_world.txt'},
#     'Clash': {'Midnight Log': 'midnight_log.txt'},
#     'Def Leppard': {'Two Steps Behind (Electric Version)': 'two_steps_behind_(electric_version).txt'},
#     'Willie Nelson': {'Wabash Cannonball': 'wabash_cannonball.txt'},
#     'Eminem': {'Asshole': 'asshole.txt'}}}},
#  'Foreigner': {'I Want To Know What Love Is': {'file_name': 'i_want_to_know_what_love_is.txt',
#    'recommendations': {'Hank Williams': {'Please Make Up Your Mind': 'please_make_up_your_mind.txt'},
#     'Chic': {'Le Freak': 'le_freak.txt'},
#     'Frank Sinatra': {'This Love Of Mine': 'this_love_of_mine.txt'},
#     'Marvin Gaye': {'The Late, Late Show': 'the_late,_late_show.txt'},
#     'Run-DMC': {'My Adidas': 'my_adidas.txt'}}}},
#  'Fergie': {"Big Girls Don'T Cry": {'file_name': "big_girls_don't_cry.txt",
#    'recommendations': {'Paul McCartney': {'Ebony And Ivory': 'ebony_and_ivory.txt'},
#     'Sam Cooke': {"That'S Heaven To Me": "that's_heaven_to_me.txt"},
#     'Beach Boys': {'The Girl From New York City': 'the_girl_from_new_york_city.txt'},
#     'Alice Cooper': {'From The Inside': 'from_the_inside.txt'},
#     'Velvet Underground': {'Lonesome Cowboy Bill': 'lonesome_cowboy_bill.txt'}}}},
#  'Bee Gees': {'How Can You Mend A Broken Heart': {'file_name': 'how_can_you_mend_a_broken_heart.txt',
#    'recommendations': {'Black Sabbath': {'Megalomania': 'megalomania.txt'},
#     'Celine Dion': {'Because You Loved Me': 'because_you_loved_me.txt'},
#     'REM': {'Radio Free Europe': 'radio_free_europe.txt'},
#     'Bo Diddley': {'Mr. Khrushchev': 'mr._khrushchev.txt'},
#     'Run-DMC': {'Get Open': 'get_open.txt'}}},
#   "Stayin' Alive": {'file_name': "stayin'_alive.txt",
#    'recommendations': {'Kraftwerk': {'Endless Endless': 'endless_endless.txt'},
#     'Everly Brothers': {"Cathy'S Clown": "cathy's_clown.txt"},
#     'Chuck Berry': {'Tell You About My Buddy': 'tell_you_about_my_buddy.txt'},
#     'Clash': {'The Right Profile': 'the_right_profile.txt'},
#     'Pharrell Williams': {'Happy': 'happy.txt'}}},
#   'Night Fever': {'file_name': 'night_fever.txt',
#    'recommendations': {'Frank Sinatra': {"Guess I'Ll Hang My Tears Out To Dry": "guess_i'll_hang_my_tears_out_to_dry.txt"},
#     'Ray Charles': {"Tell Me You'Ll Wait For Me": "tell_me_you'll_wait_for_me.txt"},
#     'Jerry Lee Lewis': {'Sea Cruise': 'sea_cruise.txt'},
#     'Rolling Stones': {'Out Of Time': 'out_of_time.txt'},
#     'Jimi Hendrix': {'Astro Man': 'astro_man.txt'}}},
#   'How Deep Is Your Love': {'file_name': 'how_deep_is_your_love.txt',
#    'recommendations': {'Little Richard': {'Function At The Junction': 'function_at_the_junction.txt'},
#     'Bo Diddley': {'Pollution': 'pollution.txt'},
#     'Jerry Lee Lewis': {'Sticks And Stones': 'sticks_and_stones.txt'},
#     'James Brown': {'The Bells': 'the_bells.txt'},
#     'Frank Sinatra': {"She'S Funny That Way": "she's_funny_that_way.txt"}}}},
#  'TLC': {'No Scrubs': {'file_name': 'no_scrubs.txt',
#    'recommendations': {'Eminem': {'Mockingbird': 'mockingbird.txt'},
#     'Little Richard': {"Slippin' And Slidin'": "slippin'_and_slidin'.txt"},
#     'Eagles': {'The Sad Cafe': 'the_sad_cafe.txt'},
#     'Jerry Lee Lewis': {'Gotta Travel On': 'gotta_travel_on.txt'},
#     'Frank Sinatra': {"I Don'T Know Why (I Just Do)": "i_don't_know_why_(i_just_do).txt"}}},
#   'Creep': {'file_name': 'creep.txt',
#    'recommendations': {'Aerosmith': {"Baby, Please Don'T Go": "baby,_please_don't_go.txt"},
#     'Eurythmics': {'In This Town': 'in_this_town.txt'},
#     'Billy Joel': {'Last Of The Big Time Spenders': 'last_of_the_big_time_spenders.txt'},
#     'ACDC': {'Can I Sit Next To You Girl': 'can_i_sit_next_to_you_girl.txt'},
#     'Willie Nelson': {'What Do You Want Me To Do?': 'what_do_you_want_me_to_do?.txt'}}},
#   'Baby-Baby-Baby': {'file_name': 'baby-baby-baby.txt',
#    'recommendations': {'Barbra Streisand': {'The Way We Were': 'the_way_we_were.txt'},
#     'Frank Sinatra': {'It All Depends On You': 'it_all_depends_on_you.txt'},
#     'KISS': {'Naked City': 'naked_city.txt'},
#     'Chuck Berry': {'Havana Moon': 'havana_moon.txt'},
#     'Prince': {'When Doves Cry': 'when_doves_cry.txt'}}}},
#  'Slayer': {'I Hate You': {'file_name': 'i_hate_you.txt',
#    'recommendations': {'Ray Charles': {'Alabamy Bound': 'alabamy_bound.txt'},
#     'Hank Williams': {"My Sweet Love Ain'T Around": "my_sweet_love_ain't_around.txt"},
#     'Daft Punk': {'Wdpk 83.7 Fm': 'wdpk_83.7_fm.txt'},
#     'Madonna': {"She'S Not Me": "she's_not_me.txt"},
#     'Rolling Stones': {'Sympathy For The Devil': 'sympathy_for_the_devil.txt'}}},
#   'Stain Of Mind': {'file_name': 'stain_of_mind.txt',
#    'recommendations': {'Willie Nelson': {'Will You Remember Mine': 'will_you_remember_mine.txt'},
#     'Ray Charles': {'I Cried For You': 'i_cried_for_you.txt'},
#     'Van Morrison': {'Venice U.S.A.': 'venice_u.s.a..txt'},
#     'Chuck Berry': {"Ma' Dear Ma' Dear": "ma'_dear_ma'_dear.txt"},
#     'Led Zeppelin': {'Out On The Tiles': 'out_on_the_tiles.txt'}}},
#   'Altar Of Sacrifice': {'file_name': 'altar_of_sacrifice.txt',
#    'recommendations': {'Righteous Brothers': {"I Can'T Make It Alone": "i_can't_make_it_alone.txt"},
#     'James Brown': {"That'S When I Lost My Heart": "that's_when_i_lost_my_heart.txt"},
#     'Blondie': {'Dragonfly': 'dragonfly.txt'},
#     'Jimi Hendrix': {'Hey Baby (New Rising Sun)': 'hey_baby_(new_rising_sun).txt'},
#     'Willie Nelson': {'On The Sunny Side Of The Street': 'on_the_sunny_side_of_the_street.txt'}}},
#   'Gemini': {'file_name': 'gemini.txt',
#    'recommendations': {'Eurythmics': {'Lifted': 'lifted.txt'},
#     'Willie Nelson': {'An Evening Prayer': 'an_evening_prayer.txt'},
#     'Turtles': {'Happy Together': 'happy_together.txt'},
#     'Bob Marley': {'Get Up, Stand Up': 'get_up,_stand_up.txt'},
#     'Ray Charles': {'That Lucky Old Sun': 'that_lucky_old_sun.txt'}}},
#   'Jesus Saves': {'file_name': 'jesus_saves.txt',
#    'recommendations': {'Bo Diddley': {'Dearest Darling': 'dearest_darling.txt'},
#     'Elvis Costello': {'Just A Memory': 'just_a_memory.txt'},
#     'Talking Heads': {'Love → Building On Fire(2005 Reissue Bonus Track)': 'love_→_building_on_fire(2005_reissue_bonus_track).txt'},
#     'Public Enemy': {'State Of The Union (Stfu)': 'state_of_the_union_(stfu).txt'}}},
#   'Vices': {'file_name': 'vices.txt',
#    'recommendations': {'Who': {'Christmas': 'christmas.txt'},
#     'Hank Williams': {"Settin' The Woods On Fire": "settin'_the_woods_on_fire.txt"},
#     'Led Zeppelin': {'Bring It On Home': 'bring_it_on_home.txt'},
#     'Sam Cooke': {'I Cover The Waterfront': 'i_cover_the_waterfront.txt'},
#     'Frank Sinatra': {'Like Someone In Love': 'like_someone_in_love.txt'}}},
#   'In The Name Of God': {'file_name': 'in_the_name_of_god.txt',
#    'recommendations': {'Ciara': {'1, 2 Step': '1,_2_step.txt'},
#     'Ray Charles': {"Ev'Ry Time We Say Goodbye": "ev'ry_time_we_say_goodbye.txt"},
#     'Hank Williams': {'Beyond The Sunset': 'beyond_the_sunset.txt'},
#     'Bo Diddley': {'Willie And Lillie': 'willie_and_lillie.txt'},
#     'Aretha Franklin': {'The Night Time Is The Right Time': 'the_night_time_is_the_right_time.txt'}}},
#   'Hardening Of The Arteries': {'file_name': 'hardening_of_the_arteries.txt',
#    'recommendations': {'Madonna': {'The Look Of Love': 'the_look_of_love.txt'},
#     'Lipps Inc': {'Funkytown': 'funkytown.txt'},
#     'Supremes': {'A Change Is Gonna Come': 'a_change_is_gonna_come.txt'},
#     'Willie Nelson': {"Mom And Dad'S Waltz": "mom_and_dad's_waltz.txt"},
#     'Simon & Garfunkel': {'Patterns': 'patterns.txt'}}},
#   'Addict(Bonus Track)': {'file_name': 'addict(bonus_track).txt',
#    'recommendations': {'Pink Floyd': {'Speak To Me': 'speak_to_me.txt'},
#     'Bo Diddley': {'I Can Tell': 'i_can_tell.txt'},
#     'Blondie': {'Slow Motion': 'slow_motion.txt'},
#     'Beach Boys': {"Don'T Hurt My Little Sister": "don't_hurt_my_little_sister.txt"},
#     'Alicia Keys': {"Fallin'": "fallin'.txt"}}},
#   'War Ensemble': {'file_name': 'war_ensemble.txt',
#    'recommendations': {'Clash': {'Long Time Jerk': 'long_time_jerk.txt'},
#     'Frank Sinatra': {'Sunday': 'sunday.txt'},
#     'Ray Charles': {'What Kind Of Man Are You': 'what_kind_of_man_are_you.txt'},
#     'Talking Heads': {'Paper': 'paper.txt'}}},
#   'Seasons In The Abyss': {'file_name': 'seasons_in_the_abyss.txt',
#    'recommendations': {'Ed Sheeran': {'Thinking Out Loud': 'thinking_out_loud.txt'},
#     'Jerry Lee Lewis': {'Roll Over Beethoven': 'roll_over_beethoven.txt'},
#     'Radiohead': {'Fog': 'fog.txt'},
#     'Marvin Gaye': {'Falling In Love Again': 'falling_in_love_again.txt'},
#     'Van Morrison': {'Spirit': 'spirit.txt'}}},
#   'Perversions Of Pain': {'file_name': 'perversions_of_pain.txt',
#    'recommendations': {'Ray Charles': {'The Naughty Lady Of Shady Lane': 'the_naughty_lady_of_shady_lane.txt'},
#     'Madonna': {'Rainbow Tour': 'rainbow_tour.txt'},
#     'Frank Sinatra': {'The Girl Next Door': 'the_girl_next_door.txt'},
#     'Def Leppard': {"You Got Me Runnin'": "you_got_me_runnin'.txt"},
#     'Marvin Gaye': {'Love Fell On Me': 'love_fell_on_me.txt'}}},
#   'Playing With Dolls': {'file_name': 'playing_with_dolls.txt',
#    'recommendations': {'Little Richard': {'Never Gonna Let You Go': 'never_gonna_let_you_go.txt'},
#     'Iron Maiden': {'Starblind': 'starblind.txt'},
#     'Pearl Jam': {'Ghost': 'ghost.txt'},
#     'Bo Diddley': {'Back Home': 'back_home.txt'},
#     'Frank Sinatra': {'Sunday': 'sunday.txt'}}},
#   'The Antichrist': {'file_name': 'the_antichrist.txt',
#    'recommendations': {'Iron Maiden': {'22 Acacia Avenue': '22_acacia_avenue.txt'},
#     'Kraftwerk': {'Computer Liebe': 'computer_liebe.txt'},
#     'Slayer': {'War Ensemble': 'war_ensemble.txt'},
#     'Run-DMC': {'Perfection': 'perfection.txt'},
#     'Supremes': {'Twinkle Twinkle Little Me': 'twinkle_twinkle_little_me.txt'}}},
#   'Human Strain': {'file_name': 'human_strain.txt',
#    'recommendations': {'KISS': {'Got Love For Sale': 'got_love_for_sale.txt'},
#     'Radiohead': {'Planet Telex': 'planet_telex.txt'},
#     'Metallica': {'Creeping Death': 'creeping_death.txt'},
#     'Hank Williams': {'I Dreamed About Mama Last Night': 'i_dreamed_about_mama_last_night.txt'},
#     'Billy Joel': {'Don\'T Worry Baby(From "My Lives" Compilation)': 'don\'t_worry_baby(from_"my_lives"_compilation).txt'}}},
#   'Supremist': {'file_name': 'supremist.txt',
#    'recommendations': {'Santana': {'Let There Be Light': 'let_there_be_light.txt'},
#     'Beach Boys': {"Don'T Hurt My Little Sister": "don't_hurt_my_little_sister.txt"},
#     'Louis Armstrong': {'Hello, Dolly!': 'hello,_dolly!.txt'},
#     'Bo Diddley': {"I'M Looking For A Woman": "i'm_looking_for_a_woman.txt"}}},
#   'Face The Slayer': {'file_name': 'face_the_slayer.txt',
#    'recommendations': {'Beach Boys': {'Hushabye': 'hushabye.txt'},
#     'Supremes': {'It Makes No Difference Now': 'it_makes_no_difference_now.txt'},
#     'LeAnn Rimes': {'How Do I Live': 'how_do_i_live.txt'},
#     'Talking Heads': {'(Love Goes To) Building On Fire': '(love_goes_to)_building_on_fire.txt'},
#     'Frank Sinatra': {'You Do Something To Me': 'you_do_something_to_me.txt'}}},
#   'Consfearacy': {'file_name': 'consfearacy.txt',
#    'recommendations': {'Chuck Berry': {'Brown Eyed Handsome Man': 'brown_eyed_handsome_man.txt'},
#     'Little Richard': {"Poor Dog (Who Can'T Wag His Own Tail)": "poor_dog_(who_can't_wag_his_own_tail).txt"},
#     'Willie Nelson': {'Sad Songs And Waltzes': 'sad_songs_and_waltzes.txt'},
#     'Kenny Loggins': {'Footloose': 'footloose.txt'}}},
#   'Ddamm (Drunk Drivers Against Mad Mothers)': {'file_name': 'ddamm_(drunk_drivers_against_mad_mothers).txt',
#    'recommendations': {'Bangles': {'Walk Like An Egyptian': 'walk_like_an_egyptian.txt'},
#     'Anthrax': {'Got The Time': 'got_the_time.txt'},
#     'Van Morrison': {'Spirit': 'spirit.txt'},
#     'Ray Charles': {'Roll With My Baby': 'roll_with_my_baby.txt'},
#     'Temptations': {'Who Can I Turn To (When Nobody Needs Me)': 'who_can_i_turn_to_(when_nobody_needs_me).txt'}}},
#   'Darkness Of Christ': {'file_name': 'darkness_of_christ.txt',
#    'recommendations': {'Outkast': {'Hootie Hoo': 'hootie_hoo.txt'},
#     'Association': {'Cherish': 'cherish.txt'},
#     'Public Enemy': {'So Whatcha Gone Do Now?': 'so_whatcha_gone_do_now?.txt'},
#     'Beatles': {"It Won'T Be Long": "it_won't_be_long.txt"}}}},
#  'Foo Fighters': {'Overdrive': {'file_name': 'overdrive.txt',
#    'recommendations': {'Santana': {'Stone Flower': 'stone_flower.txt'},
#     'Pink Floyd': {'A Spanish Piece': 'a_spanish_piece.txt'},
#     'Metallica': {'The Small Hours': 'the_small_hours.txt'},
#     'Mariah Carey': {'We Belong Together': 'we_belong_together.txt'},
#     'Jay-Z': {'Green Light': 'green_light.txt'}}},
#   'Miss The Misery': {'file_name': 'miss_the_misery.txt',
#    'recommendations': {'Run-DMC': {'Papa Crazy': 'papa_crazy.txt'},
#     'Simon & Garfunkel': {'Barbriallen(From "The Columbia Studio Recordings (1964–1970)" Box Set)': 'barbriallen(from_"the_columbia_studio_recordings_(1964–1970)"_box_set).txt'},
#     'Genesis': {'You Might Recall': 'you_might_recall.txt'},
#     'Ray Charles': {"It'S Alright": "it's_alright.txt"},
#     'Beach Boys': {'California Girls': 'california_girls.txt'}}},
#   'Halo': {'file_name': 'halo.txt',
#    'recommendations': {'Temptations': {'My Girl': 'my_girl.txt'},
#     'Ray Charles': {'Mess Around': 'mess_around.txt'},
#     'Frank Sinatra': {'Fools Rush In': 'fools_rush_in.txt'},
#     'Shania Twain': {"You'Re Still The One": "you're_still_the_one.txt"},
#     'Righteous Brothers': {"I'M Leaving It Up To You": "i'm_leaving_it_up_to_you.txt"}}},
#   'The Pretender': {'file_name': 'the_pretender.txt',
#    'recommendations': {'Phil Collins': {'Against All Odds (Take A Look At Me Now)': 'against_all_odds_(take_a_look_at_me_now).txt'},
#     'Aerosmith': {'My Girl': 'my_girl.txt'},
#     'Ray Charles': {'Heartbreaker': 'heartbreaker.txt'},
#     'Diana Ross': {'Touch Me In The Morning': 'touch_me_in_the_morning.txt'}}},
#   'Danny Says(Special Limited Edition Bonus Track)': {'file_name': 'danny_says(special_limited_edition_bonus_track).txt',
#    'recommendations': {'Eurythmics': {'Adrian': 'adrian.txt'},
#     'Black Sabbath': {'Keep It Warm': 'keep_it_warm.txt'},
#     'Post Malone': {'Rockstar': 'rockstar.txt'},
#     'Frank Sinatra': {'I Concentrate On You': 'i_concentrate_on_you.txt'},
#     'Radiohead': {'Banana Co.': 'banana_co..txt'}}},
#   'My Poor Brain': {'file_name': 'my_poor_brain.txt',
#    'recommendations': {'Run-DMC': {'Is It Live': 'is_it_live.txt'},
#     'Queen': {"'39": "'39.txt"},
#     'Talking Heads': {'What A Day That Was': 'what_a_day_that_was.txt'},
#     'Police': {'Every Breath You Take': 'every_breath_you_take.txt'},
#     'Klymaxx': {'I Miss You': 'i_miss_you.txt'}}},
#   'X-Static': {'file_name': 'x-static.txt',
#    'recommendations': {'Alice Cooper': {'A Bedtime Story': 'a_bedtime_story.txt'},
#     'Ray Charles': {"Swanee River Rock (Talkin' 'Bout That River)": "swanee_river_rock_(talkin'_'bout_that_river).txt"},
#     'ACDC': {"Can'T Stand Still": "can't_stand_still.txt"},
#     'Nirvana': {'Sifting': 'sifting.txt'},
#     'Marvin Gaye': {'Why Did I Choose You?': 'why_did_i_choose_you?.txt'}}},
#   'A Matter Of Time': {'file_name': 'a_matter_of_time.txt',
#    'recommendations': {'Run-DMC': {"You'Re Blind": "you're_blind.txt"},
#     'Buddy Holly': {'You Are My One Desire': 'you_are_my_one_desire.txt'},
#     'Metallica': {'The Small Hours': 'the_small_hours.txt'},
#     'Ray Charles': {'Everybody Has The Blues(2005 Reissue Bonus Track)': 'everybody_has_the_blues(2005_reissue_bonus_track).txt'},
#     'Jimi Hendrix': {'Astro Man': 'astro_man.txt'}}},
#   'Sunday Rain': {'file_name': 'sunday_rain.txt',
#    'recommendations': {'Righteous Brothers': {'I Just Want To Make Love To You': 'i_just_want_to_make_love_to_you.txt'},
#     'Beatles': {'Oh! Darling': 'oh!_darling.txt'},
#     'Black Sabbath': {'Megalomania': 'megalomania.txt'},
#     'Vertical Horizon': {'Everything You Want': 'everything_you_want.txt'},
#     'James Brown': {'Tell Me What I Did Wrong': 'tell_me_what_i_did_wrong.txt'}}},
#   'Iron Rooster': {'file_name': 'iron_rooster.txt',
#    'recommendations': {'Police': {'Demolition Man': 'demolition_man.txt'},
#     'Bee Gees': {'How Deep Is Your Love': 'how_deep_is_your_love.txt'},
#     'Jimi Hendrix': {"(I'M Your) Hoochie Coochie Man": "(i'm_your)_hoochie_coochie_man.txt"},
#     'Hank Williams': {"Just Waitin'": "just_waitin'.txt"},
#     'Bo Diddley': {'Hush Your Mouth': 'hush_your_mouth.txt'}}},
#   "Ain'T It The Life": {'file_name': "ain't_it_the_life.txt",
#    'recommendations': {'Van Morrison': {'Sweet Jannie': 'sweet_jannie.txt'},
#     'Pink Floyd': {'Crying Song': 'crying_song.txt'},
#     'Bob Marley': {'Who The Cap Fit': 'who_the_cap_fit.txt'},
#     'Buddy Holly': {'Midnight Shift': 'midnight_shift.txt'},
#     'Captain & Tennille': {'Love Will Keep Us Together': 'love_will_keep_us_together.txt'}}},
#   'Once & For All(Japanese Bonus Track)': {'file_name': 'once_&_for_all(japanese_bonus_track).txt',
#    'recommendations': {'Bee Gees': {'How Can You Mend A Broken Heart': 'how_can_you_mend_a_broken_heart.txt'},
#     'Ray Charles': {'Rock And Roll Shoes': 'rock_and_roll_shoes.txt'},
#     'Bo Diddley': {'Bo Diddley Is Loose': 'bo_diddley_is_loose.txt'},
#     'Buddy Holly': {'Tell Me How': 'tell_me_how.txt'},
#     'Jay-Z': {"It'S Alright": "it's_alright.txt"}}},
#   'Monkey Wrench': {'file_name': 'monkey_wrench.txt',
#    'recommendations': {'Prince': {'Npg Operator': 'npg_operator.txt'},
#     'Jerry Lee Lewis': {'Breathless': 'breathless.txt'},
#     'Aerosmith': {"Baby, Please Don'T Go": "baby,_please_don't_go.txt"},
#     'Little Richard': {'Shake A Hand': 'shake_a_hand.txt'},
#     'Clash': {'Straight To Hell': 'straight_to_hell.txt'}}},
#   'La Dee Da': {'file_name': 'la_dee_da.txt',
#    'recommendations': {'Bo Diddley': {'I Just Want To Make Love To You(From "Super Blues" Album)': 'i_just_want_to_make_love_to_you(from_"super_blues"_album).txt'},
#     'Nirvana': {'Love Buzz': 'love_buzz.txt'},
#     'Run-DMC': {'Is It Live': 'is_it_live.txt'},
#     'Outkast': {'Slum Beautiful': 'slum_beautiful.txt'},
#     'Terry Jacks': {'Seasons In The Sun': 'seasons_in_the_sun.txt'}}},
#   'Live-In Skin': {'file_name': 'live-in_skin.txt',
#    'recommendations': {'Bo Diddley': {'I Love You So': 'i_love_you_so.txt'},
#     'Led Zeppelin': {"That'S The Way": "that's_the_way.txt"},
#     'Run-DMC': {'Darryl And Joe (Krush-Groove 3)': 'darryl_and_joe_(krush-groove_3).txt'},
#     'KISS': {'Got Love For Sale': 'got_love_for_sale.txt'}}},
#   'Outside': {'file_name': 'outside.txt',
#    'recommendations': {'Def Leppard': {'Sorrow Is A Woman': 'sorrow_is_a_woman.txt'},
#     'Eminem': {'Rain Man': 'rain_man.txt'},
#     'Nirvana': {'Anorexorcist': 'anorexorcist.txt'},
#     'Everly Brothers': {'Autumn Leaves': 'autumn_leaves.txt'},
#     'Clash': {'Safe European Home': 'safe_european_home.txt'}}},
#   'The Colour And The Shape(Bonus Track)': {'file_name': 'the_colour_and_the_shape(bonus_track).txt',
#    'recommendations': {'Usher': {'Omg': 'omg.txt'},
#     'Ed Sheeran': {'Thinking Out Loud': 'thinking_out_loud.txt'},
#     'Blondie': {'A Rose By Any Name': 'a_rose_by_any_name.txt'},
#     'Beach Boys': {'Little Deuce Coupe': 'little_deuce_coupe.txt'},
#     'Prince': {'The Max': 'the_max.txt'}}},
#   'Winnebago(Japanese Bonus Track)': {'file_name': 'winnebago(japanese_bonus_track).txt',
#    'recommendations': {'Jay-Z': {'Green Light': 'green_light.txt'},
#     'Iron Maiden': {'Ghost Of The Navigator': 'ghost_of_the_navigator.txt'},
#     'Jimi Hendrix': {'Blue Suede Shoes': 'blue_suede_shoes.txt'},
#     'Foo Fighters': {'A Matter Of Time': 'a_matter_of_time.txt'},
#     'OneRepublic': {'Counting Stars': 'counting_stars.txt'}}},
#   'Dirty Water': {'file_name': 'dirty_water.txt',
#    'recommendations': {'Van Morrison': {'Lifetimes': 'lifetimes.txt'},
#     'Bob Marley': {'Duppy Conqueror': 'duppy_conqueror.txt'},
#     'Frank Sinatra': {'With Every Breath I Take': 'with_every_breath_i_take.txt'},
#     'Supremes': {"The Only Time I'M Happy": "the_only_time_i'm_happy.txt"}}},
#   'Podunk(Japanese Bonus Track)': {'file_name': 'podunk(japanese_bonus_track).txt',
#    'recommendations': {'Anthrax': {'Subjugator': 'subjugator.txt'},
#     'Ray Charles': {'Georgia On My Mind': 'georgia_on_my_mind.txt'},
#     'Beatles': {'What Goes On': 'what_goes_on.txt'},
#     'Nirvana': {"Ain'T It A Shame": "ain't_it_a_shame.txt"},
#     'Led Zeppelin': {"Babe, I'M Gonna Leave You": "babe,_i'm_gonna_leave_you.txt"}}}},
#  'Halsey': {'Without Me': {'file_name': 'without_me.txt',
#    'recommendations': {'Def Leppard': {'Wasted': 'wasted.txt'},
#     'Little Richard': {'Lawdy Miss Claudie': 'lawdy_miss_claudie.txt'},
#     'Jerry Lee Lewis': {'Sweet Dreams': 'sweet_dreams.txt'},
#     'Chuck Berry': {"You Can'T Catch Me(2004 Reissue Bonus Track)": "you_can't_catch_me(2004_reissue_bonus_track).txt"}}}},
#  'Temptations': {"You Don'T Love Me No More": {'file_name': "you_don't_love_me_no_more.txt",
#    'recommendations': {'Led Zeppelin': {'Thank You': 'thank_you.txt'},
#     'Chuck Berry': {'Good Morning Little Schoolgirl': 'good_morning_little_schoolgirl.txt'},
#     'George Michael': {'Faith': 'faith.txt'},
#     'Frank Sinatra': {'Sunday': 'sunday.txt'},
#     'Radiohead': {'Sail To The Moon': 'sail_to_the_moon.txt'}}},
#   'Try To Remember': {'file_name': 'try_to_remember.txt',
#    'recommendations': {'Judas Priest': {'Metal Messiah': 'metal_messiah.txt'},
#     'Elvis Costello': {'Shoes Without Heels': 'shoes_without_heels.txt'},
#     'Maroon 5': {'Sugar': 'sugar.txt'},
#     'Little Richard': {"I'M Just A Lonely Guy": "i'm_just_a_lonely_guy.txt"},
#     'Iron Maiden': {'Starblind': 'starblind.txt'}}},
#   'Touch Me Again': {'file_name': 'touch_me_again.txt',
#    'recommendations': {'Everly Brothers': {"I'Ve Been Wrong Before": "i've_been_wrong_before.txt"},
#     'Blondie': {'The Hunter Gets Captured By The Game': 'the_hunter_gets_captured_by_the_game.txt'},
#     'Willie Nelson': {'Permanently Lonely': 'permanently_lonely.txt'},
#     'Beach Boys': {"Surfin' Usa": "surfin'_usa.txt"},
#     'Jay-Z': {"Big Pimpin'": "big_pimpin'.txt"}}},
#   'Save My Love For A Rainy Day': {'file_name': 'save_my_love_for_a_rainy_day.txt',
#    'recommendations': {'Slayer': {'Altar Of Sacrifice': 'altar_of_sacrifice.txt'},
#     'Elvis Costello': {'Busy Bodies': 'busy_bodies.txt'},
#     'Genesis': {'You Might Recall': 'you_might_recall.txt'},
#     'Chuck Berry': {'California': 'california.txt'},
#     'KISS': {'Little Caesar': 'little_caesar.txt'}}},
#   "It'S Summer": {'file_name': "it's_summer.txt",
#    'recommendations': {'Slayer': {'Stain Of Mind': 'stain_of_mind.txt'},
#     'Judas Priest': {'Night Crawler': 'night_crawler.txt'},
#     'Little Richard': {"I'M Just A Lonely Guy": "i'm_just_a_lonely_guy.txt"},
#     'Gwen Stefani': {'Hollaback Girl': 'hollaback_girl.txt'},
#     'Heart': {'Alone': 'alone.txt'}}},
#   'Go For It': {'file_name': 'go_for_it.txt',
#    'recommendations': {'Aerosmith': {"Baby, Please Don'T Go": "baby,_please_don't_go.txt"},
#     'Smokey Robinson & The Miracles': {'The Tracks Of My Tears': 'the_tracks_of_my_tears.txt'},
#     'Ray Charles': {'I Had A Dream': 'i_had_a_dream.txt'},
#     'Prince': {'The Max': 'the_max.txt'},
#     'Aretha Franklin': {"That'S All I Want From You": "that's_all_i_want_from_you.txt"}}},
#   'My Girl': {'file_name': 'my_girl.txt',
#    'recommendations': {'REM': {'Perfect Circle': 'perfect_circle.txt'},
#     'Jerry Lee Lewis': {'Hey Baby': 'hey_baby.txt'},
#     'Prince': {'So Blue': 'so_blue.txt'},
#     'Hank Williams': {'Men With Broken Hearts': 'men_with_broken_hearts.txt'},
#     'Rolling Stones': {'Out Of Time': 'out_of_time.txt'}}},
#   "Ain'T No Sun Since You'Ve Been Gone": {'file_name': "ain't_no_sun_since_you've_been_gone.txt",
#    'recommendations': {'Def Leppard': {'Day After Day': 'day_after_day.txt'},
#     'Marvin Gaye': {'The Late, Late Show': 'the_late,_late_show.txt'},
#     'Van Morrison': {'Rave On, John Donne': 'rave_on,_john_donne.txt'},
#     'Metallica': {'Creeping Death': 'creeping_death.txt'},
#     'Madonna': {'Best Night(Deluxe Edition Bonus Track)': 'best_night(deluxe_edition_bonus_track).txt'}}},
#   'Take A Look Around': {'file_name': 'take_a_look_around.txt',
#    'recommendations': {'Black Sabbath': {'Megalomania': 'megalomania.txt'},
#     'Run-DMC': {'Get Open': 'get_open.txt'},
#     'Dean Martin': {'Everybody Loves Somebody': 'everybody_loves_somebody.txt'},
#     'Nelly': {'Hot In Herre': 'hot_in_herre.txt'},
#     'Clash': {'Long Time Jerk': 'long_time_jerk.txt'}}},
#   "Don'T Let Him Take Your Love From Me": {'file_name': "don't_let_him_take_your_love_from_me.txt",
#    'recommendations': {'Who': {'Mirror Door': 'mirror_door.txt'},
#     'Hank Williams': {'The Funeral': 'the_funeral.txt'},
#     'Frank Sinatra': {'You Brought A New Kind Of Love To Me': 'you_brought_a_new_kind_of_love_to_me.txt'},
#     'Public Enemy': {'Mind Terrorist': 'mind_terrorist.txt'},
#     'Bo Diddley': {'Oh Yea': 'oh_yea.txt'}}},
#   'Everything For Christmas': {'file_name': 'everything_for_christmas.txt',
#    'recommendations': {'Buddy Holly': {"It'S Too Late": "it's_too_late.txt"},
#     'Public Enemy': {"Don'T Give Up The Fight": "don't_give_up_the_fight.txt"},
#     'Bo Diddley': {'Come On Baby': 'come_on_baby.txt'},
#     'Anthrax': {'Subjugator': 'subjugator.txt'},
#     'Frank Sinatra': {'I Concentrate On You': 'i_concentrate_on_you.txt'}}},
#   'Let Me Count The Ways (I Love You)': {'file_name': 'let_me_count_the_ways_(i_love_you).txt',
#    'recommendations': {'Timbaland': {'Apologize': 'apologize.txt'},
#     'Hank Williams': {'Six More Miles (To The Graveyard)': 'six_more_miles_(to_the_graveyard).txt'},
#     'Ray Charles': {'One Mint Julep': 'one_mint_julep.txt'},
#     'Foo Fighters': {'X-Static': 'x-static.txt'},
#     'Bo Diddley': {'Working Man(1988 Bonus Track)': 'working_man(1988_bonus_track).txt'}}},
#   'Fan The Flame': {'file_name': 'fan_the_flame.txt',
#    'recommendations': {'Peaches & Herb': {'Reunited': 'reunited.txt'},
#     'Supremes': {"(He'S) Seventeen": "(he's)_seventeen.txt"},
#     'Bob Marley': {'Easy Skanking': 'easy_skanking.txt'},
#     'Grand Funk Railroad': {'The Loco-Motion': 'the_loco-motion.txt'},
#     'Ray Charles': {"New York'S My Home": "new_york's_my_home.txt"}}},
#   'Girls (They Like It)': {'file_name': 'girls_(they_like_it).txt',
#    'recommendations': {'Kendrick Lamar': {'Humble': 'humble.txt'},
#     'Marvin Gaye': {'How Can I Forget': 'how_can_i_forget.txt'},
#     'Irene Cara': {'Flashdance... What A Feeling': 'flashdance..._what_a_feeling.txt'},
#     'Led Zeppelin': {'Going To California': 'going_to_california.txt'},
#     'Hank Williams': {"Nobody'S Lonesome For Me": "nobody's_lonesome_for_me.txt"}}},
#   'Who Can I Turn To (When Nobody Needs Me)': {'file_name': 'who_can_i_turn_to_(when_nobody_needs_me).txt',
#    'recommendations': {'Billy Joel': {"Where'S The Orchestra?": "where's_the_orchestra?.txt"},
#     'Beatles': {'Little Child': 'little_child.txt'},
#     'Hall & Oates': {'Thank You For...': 'thank_you_for....txt'},
#     'Metallica': {"Now That We'Re Dead": "now_that_we're_dead.txt"},
#     'KISS': {'Creatures Of The Night': 'creatures_of_the_night.txt'}}},
#   'Is There Anybody Else': {'file_name': 'is_there_anybody_else.txt',
#    'recommendations': {'Rolling Stones': {'Midnight Rambler': 'midnight_rambler.txt'},
#     'Pearl Jam': {'Hitchhiker': 'hitchhiker.txt'},
#     'Prince': {'When Doves Cry': 'when_doves_cry.txt'},
#     'Marvin Gaye': {"That'S The Way Love Is": "that's_the_way_love_is.txt"},
#     'Willie Nelson': {"Who'S Sorry Now?": "who's_sorry_now?.txt"}}},
#   'Love On My Mind Tonight': {'file_name': 'love_on_my_mind_tonight.txt',
#    'recommendations': {'Little Richard': {"I Don'T Want To Discuss It": "i_don't_want_to_discuss_it.txt"},
#     'Police': {'Visions Of The Night(From "Walking On The Moon" Single)': 'visions_of_the_night(from_"walking_on_the_moon"_single).txt'},
#     'Bo Diddley': {'Gunslinger': 'gunslinger.txt'},
#     'Santana': {'All I Ever Wanted': 'all_i_ever_wanted.txt'},
#     'Aerosmith': {'Critical Mass': 'critical_mass.txt'}}},
#   'Happy People': {'file_name': 'happy_people.txt',
#    'recommendations': {'Led Zeppelin': {'Baby, Come On Home(Bonus Tracks Available On "Complete Studio Recordings" Box Set Version Of Coda)': 'baby,_come_on_home(bonus_tracks_available_on_"complete_studio_recordings"_box_set_version_of_coda).txt'},
#     'Anthrax': {'I Am The Law': 'i_am_the_law.txt'},
#     'Prince': {'When Doves Cry': 'when_doves_cry.txt'},
#     'Bo Diddley': {'Doing The Craw-Daddy': 'doing_the_craw-daddy.txt'},
#     'Foo Fighters': {'Miss The Misery': 'miss_the_misery.txt'}}},
#   'Treat Her Like A Lady': {'file_name': 'treat_her_like_a_lady.txt',
#    'recommendations': {'Aerosmith': {'Beyond Beautiful': 'beyond_beautiful.txt'},
#     'Eminem': {'Murder Murder': 'murder_murder.txt'},
#     'Rolling Stones': {'Sympathy For The Devil': 'sympathy_for_the_devil.txt'},
#     'Frank Sinatra': {'It All Depends On You': 'it_all_depends_on_you.txt'},
#     'Eurythmics': {'No Fear, No Hate, No Pain (No Broken Hearts)': 'no_fear,_no_hate,_no_pain_(no_broken_hearts).txt'}}},
#   "You'Ve Got To Earn It": {'file_name': "you've_got_to_earn_it.txt",
#    'recommendations': {'Judas Priest': {'Turbo Lover': 'turbo_lover.txt'},
#     'Run-DMC': {'Darryl And Joe (Krush-Groove 3)': 'darryl_and_joe_(krush-groove_3).txt'},
#     'Ray Charles': {"Dream (When You'Re Feeling Blue)": "dream_(when_you're_feeling_blue).txt"},
#     'Frank Sinatra': {"It'S Only A Paper Moon": "it's_only_a_paper_moon.txt"},
#     'Hall & Oates': {"70'S Scenario": "70's_scenario.txt"}}},
#   'Just My Imagination (Running Away With Me)': {'file_name': 'just_my_imagination_(running_away_with_me).txt',
#    'recommendations': {'Def Leppard': {'Stand Up (Kick Love Into Motion)': 'stand_up_(kick_love_into_motion).txt'},
#     'Frank Sinatra': {'Ill Wind': 'ill_wind.txt'},
#     'Ray Charles': {'I Want A Little Girl': 'i_want_a_little_girl.txt'},
#     'Iron Maiden': {'Back In The Village': 'back_in_the_village.txt'},
#     'Van Halen': {'House Of Pain': 'house_of_pain.txt'}}},
#   "I Can'T Get Next To You": {'file_name': "i_can't_get_next_to_you.txt",
#    'recommendations': {'Ray Charles': {'Deep In The Heart Of Texas': 'deep_in_the_heart_of_texas.txt'},
#     'Chuck Berry': {'Fish And Chips': 'fish_and_chips.txt'},
#     'Little Richard': {'Goodnight Irene': 'goodnight_irene.txt'},
#     'George Harrison': {'Got My Mind Set On You': 'got_my_mind_set_on_you.txt'},
#     'Clash': {'Midnight Log': 'midnight_log.txt'}}},
#   'Glass House': {'file_name': 'glass_house.txt',
#    'recommendations': {'Billy Joel': {'Everybody Has A Dream': 'everybody_has_a_dream.txt'},
#     'Rolling Stones': {'Before They Make Me Run': 'before_they_make_me_run.txt'},
#     'Taylor Swift': {'Love Story': 'love_story.txt'},
#     'Jerry Lee Lewis': {'Room Foll Of Roses': 'room_foll_of_roses.txt'},
#     'Olivia Newton-John': {'Magic': 'magic.txt'}}}},
#  'Luis Fonsi': {'Despacito (Remix)': {'file_name': 'despacito_(remix).txt',
#    'recommendations': {'Radiohead': {'Karma Police': 'karma_police.txt'},
#     'Ray Charles': {'The Midnight Hour': 'the_midnight_hour.txt'},
#     'Archie Bell & the Drells': {'Tighten Up': 'tighten_up.txt'},
#     'Willie Nelson': {'December Day': 'december_day.txt'},
#     'Velvet Underground': {'Coyote': 'coyote.txt'}}}},
#  'Supremes': {'Nothing Can Change This Love': {'file_name': 'nothing_can_change_this_love.txt',
#    'recommendations': {'Beach Boys': {'Hushabye': 'hushabye.txt'},
#     'Queen': {'Play The Game': 'play_the_game.txt'},
#     'Marvin Gaye': {'Woman Of The World': 'woman_of_the_world.txt'},
#     'Temptations': {'Touch Me Again': 'touch_me_again.txt'},
#     'Talking Heads': {'I Feel It In My Heart(2005 Reissue Bonus Track)': 'i_feel_it_in_my_heart(2005_reissue_bonus_track).txt'}}},
#   'Twinkle Twinkle Little Me': {'file_name': 'twinkle_twinkle_little_me.txt',
#    'recommendations': {'Queen': {'Las Palabras De Amor (The Words Of Love)': 'las_palabras_de_amor_(the_words_of_love).txt'},
#     'Police': {'Be My Girl - Sally': 'be_my_girl_-_sally.txt'},
#     'Manhattans': {'Kiss And Say Goodbye': 'kiss_and_say_goodbye.txt'},
#     'Chuck Berry': {'Bye Bye Johnny': 'bye_bye_johnny.txt'},
#     'Temptations': {'Who Can I Turn To (When Nobody Needs Me)': 'who_can_i_turn_to_(when_nobody_needs_me).txt'}}},
#   'Funny How Time Slips Away': {'file_name': 'funny_how_time_slips_away.txt',
#    'recommendations': {'Rolling Stones': {"(I Can'T Get No) Satisfaction": "(i_can't_get_no)_satisfaction.txt"},
#     'Jerry Lee Lewis': {'Too Much To Gain To Lose': 'too_much_to_gain_to_lose.txt'},
#     'Chuck Berry': {'Good Morning Little Schoolgirl': 'good_morning_little_schoolgirl.txt'},
#     'Ed Sheeran': {'Thinking Out Loud': 'thinking_out_loud.txt'}}},
#   'A Change Is Gonna Come': {'file_name': 'a_change_is_gonna_come.txt',
#    'recommendations': {'Hank Williams': {"I Just Don'T Like This Kind Of Livin'": "i_just_don't_like_this_kind_of_livin'.txt"},
#     'INXS': {'Need You Tonight': 'need_you_tonight.txt'},
#     'KISS': {'Prisoner Of Love': 'prisoner_of_love.txt'},
#     'Bo Diddley': {"Crackin' Up": "crackin'_up.txt"},
#     'Kraftwerk': {'Vitamin': 'vitamin.txt'}}},
#   "The Only Time I'M Happy": {'file_name': "the_only_time_i'm_happy.txt",
#    'recommendations': {'Righteous Brothers': {"What'D I Say": "what'd_i_say.txt"},
#     'Eurythmics': {'Shame': 'shame.txt'},
#     'Hank Williams': {'Mind Your Own Business': 'mind_your_own_business.txt'},
#     'Little Richard': {'It Takes Everything To Serve The Lord': 'it_takes_everything_to_serve_the_lord.txt'}}},
#   'Joy To The World': {'file_name': 'joy_to_the_world.txt',
#    'recommendations': {'Elvis Costello': {'Big Boys': 'big_boys.txt'},
#     'Genesis': {'Dreaming While You Sleep': 'dreaming_while_you_sleep.txt'},
#     'Rod Stewart': {"Tonight'S The Night (Gonna Be Alright)": "tonight's_the_night_(gonna_be_alright).txt"},
#     'Willie Nelson': {'Why Me': 'why_me.txt'},
#     'Slayer': {'Seasons In The Abyss': 'seasons_in_the_abyss.txt'}}},
#   'You Bring Back Memories': {'file_name': 'you_bring_back_memories.txt',
#    'recommendations': {'KISS': {"I'Ve Had Enough (Into The Fire)": "i've_had_enough_(into_the_fire).txt"},
#     'Ray Charles': {'Fools Rush In': 'fools_rush_in.txt'},
#     'Iron Maiden': {'Twilight Zone': 'twilight_zone.txt'},
#     'Madonna': {'Like It Or Not': 'like_it_or_not.txt'},
#     'Chuck Berry': {'Good Morning Little Schoolgirl': 'good_morning_little_schoolgirl.txt'}}},
#   'Your Heart Belongs To Me': {'file_name': 'your_heart_belongs_to_me.txt',
#    'recommendations': {'Frank Sinatra': {"It'S Only A Paper Moon": "it's_only_a_paper_moon.txt"},
#     'Lulu': {'To Sir With Love': 'to_sir_with_love.txt'},
#     'Bo Diddley': {'Road Runner': 'road_runner.txt'},
#     'Hank Williams': {'(I Heard That) Lonesome Whistle': '(i_heard_that)_lonesome_whistle.txt'},
#     'Foo Fighters': {"Ain'T It The Life": "ain't_it_the_life.txt"}}},
#   'Your Kiss Of Fire': {'file_name': 'your_kiss_of_fire.txt',
#    'recommendations': {'Anthrax': {'I Am The Law': 'i_am_the_law.txt'},
#     'Supremes': {'Your Kiss Of Fire': 'your_kiss_of_fire.txt'},
#     'Little Richard': {"I'Ll Never Let You Go": "i'll_never_let_you_go.txt"},
#     'Frank Sinatra': {'Love Locked Out': 'love_locked_out.txt'},
#     'Elvis Costello': {'Radio Radio': 'radio_radio.txt'}}},
#   'I Want A Guy': {'file_name': 'i_want_a_guy.txt',
#    'recommendations': {'Van Halen': {'Finish What Ya Started': 'finish_what_ya_started.txt'},
#     'James Blunt': {"You'Re Beautiful": "you're_beautiful.txt"},
#     'Buddy Holly': {'Ting-A-Ling': 'ting-a-ling.txt'},
#     'Hank Williams': {"Wealth Won'T Save Your Soul": "wealth_won't_save_your_soul.txt"},
#     'Run-DMC': {"Livin' In The City": "livin'_in_the_city.txt"}}},
#   'You Need Me': {'file_name': 'you_need_me.txt',
#    'recommendations': {'Heart': {'Alone': 'alone.txt'},
#     'Jim Reeves': {"He'Ll Have To Go": "he'll_have_to_go.txt"},
#     'Sam Cooke': {'So Long': 'so_long.txt'},
#     'Bo Diddley': {"I'M A Man": "i'm_a_man.txt"},
#     'Public Enemy': {'Rebirth': 'rebirth.txt'}}},
#   "A Hard Day'S Night": {'file_name': "a_hard_day's_night.txt",
#    'recommendations': {'Marvin Gaye': {"That'S The Way Love Is": "that's_the_way_love_is.txt"},
#     'Jerry Lee Lewis': {'When Baby Gets The Blues': 'when_baby_gets_the_blues.txt'},
#     'Aerosmith': {'Pink': 'pink.txt'},
#     'Sam Cooke': {'You Send Me': 'you_send_me.txt'},
#     'Celine Dion': {'Because You Loved Me': 'because_you_loved_me.txt'}}},
#   'Time Changes Things': {'file_name': 'time_changes_things.txt',
#    'recommendations': {'Anthrax': {'Subjugator': 'subjugator.txt'},
#     'Doors': {'The Movie': 'the_movie.txt'},
#     'Alice Cooper': {"I'M Always Chasing Rainbows": "i'm_always_chasing_rainbows.txt"},
#     'Rita Coolidge': {'(Your Love Has Lifted Me) Higher And Higher': '(your_love_has_lifted_me)_higher_and_higher.txt'},
#     'Buddy Holly': {"(You'Re So Square) Baby I Don'T Care": "(you're_so_square)_baby_i_don't_care.txt"}}},
#   'It Makes No Difference Now': {'file_name': 'it_makes_no_difference_now.txt',
#    'recommendations': {'Elvis Costello': {'Hoover Factory': 'hoover_factory.txt'},
#     'Slayer': {'Perversions Of Pain': 'perversions_of_pain.txt'},
#     'Little Richard': {'Rip It Up': 'rip_it_up.txt'},
#     'Usher': {'Burn': 'burn.txt'},
#     'Bo Diddley': {"Crackin' Up": "crackin'_up.txt"}}},
#   '(The Man With The) Rock And Roll Banjo Band': {'file_name': '(the_man_with_the)_rock_and_roll_banjo_band.txt',
#    'recommendations': {'Iron Maiden': {'Another Life': 'another_life.txt'},
#     'Eurythmics': {'Lifted': 'lifted.txt'},
# ...
#    'recommendations': {'Paula Abdul': {'Rush Rush': 'rush_rush.txt'},
#     'Usher': {'Burn': 'burn.txt'},
#     'Phil Collins': {'Against All Odds (Take A Look At Me Now)': 'against_all_odds_(take_a_look_at_me_now).txt'},
#     'KISS': {'Got Love For Sale': 'got_love_for_sale.txt'},
#     'Frank Sinatra': {"She'S Funny That Way": "she's_funny_that_way.txt"}}},
#   'Flight Of Icarus': {'file_name': 'flight_of_icarus.txt',
#    'recommendations': {'Buddy Holly': {"Don'T Come Back Knockin'": "don't_come_back_knockin'.txt"},
#     'Foo Fighters': {'Outside': 'outside.txt'},
#     'Public Enemy': {'Rebel Without A Pause': 'rebel_without_a_pause.txt'},
#     'Bo Diddley': {'Before You Accuse Me': 'before_you_accuse_me.txt'},
#     'Radiohead': {'Fog': 'fog.txt'}}},
#   'Run To The Hills': {'file_name': 'run_to_the_hills.txt',
#    'recommendations': {'Willie Nelson': {'Ashamed': 'ashamed.txt'},
#     'Simon & Garfunkel': {"Why Don'T You Write Me": "why_don't_you_write_me.txt"},
#     'Ray Charles': {'I Cried For You': 'i_cried_for_you.txt'},
#     'Pink Floyd': {'Crying Song': 'crying_song.txt'},
#     'KISS': {'Calling Dr. Love': 'calling_dr._love.txt'}}},
#   'Remember Tomorrow': {'file_name': 'remember_tomorrow.txt',
#    'recommendations': {'Hank Williams': {"I'M A Long Gone Daddy": "i'm_a_long_gone_daddy.txt"},
#     'Def Leppard': {'Scar': 'scar.txt'},
#     'Run-DMC': {'Hollis Crew (Krush-Groove 2)': 'hollis_crew_(krush-groove_2).txt'},
#     'Billy Joel': {'Last Of The Big Time Spenders': 'last_of_the_big_time_spenders.txt'},
#     'Aretha Franklin': {"It'S So Heartbreakin'": "it's_so_heartbreakin'.txt"}}},
#   'To Tame A Land': {'file_name': 'to_tame_a_land.txt',
#    'recommendations': {'Hall & Oates': {'Thank You For...': 'thank_you_for....txt'},
#     'REM': {'Burning Down': 'burning_down.txt'},
#     'Beach Boys': {'Bluebirds Over The Mountain': 'bluebirds_over_the_mountain.txt'},
#     'Aerosmith': {'Fever': 'fever.txt'},
#     'Alice Cooper': {'Ballad Of Dwight Fry': 'ballad_of_dwight_fry.txt'}}},
#   '22 Acacia Avenue': {'file_name': '22_acacia_avenue.txt',
#    'recommendations': {'Billy Joel': {'Scandinavian Skies': 'scandinavian_skies.txt'},
#     'Bo Diddley': {'My Babe': 'my_babe.txt'},
#     'Chuck Berry': {'Memphis, Tennessee': 'memphis,_tennessee.txt'},
#     'Elvis Costello': {'Lovable': 'lovable.txt'},
#     'Iron Maiden': {'To Tame A Land': 'to_tame_a_land.txt'}}},
#   'No Prayer For The Dying': {'file_name': 'no_prayer_for_the_dying.txt',
#    'recommendations': {'Kenny Loggins': {'Footloose': 'footloose.txt'},
#     'Public Enemy': {'Beyond Trayvon': 'beyond_trayvon.txt'},
#     'Aerosmith': {'Simoriah': 'simoriah.txt'},
#     'Little Richard': {'Shake A Hand': 'shake_a_hand.txt'},
#     'Ray Charles': {'Sweet Georgia Brown': 'sweet_georgia_brown.txt'}}},
#   'Back In The Village': {'file_name': 'back_in_the_village.txt',
#    'recommendations': {'Pearl Jam': {'Parting Ways': 'parting_ways.txt'},
#     'Beach Boys': {'Do You Wanna Dance?': 'do_you_wanna_dance?.txt'},
#     'Marvin Gaye': {"It'S Got To Be A Miracle (This Thing Called Love)": "it's_got_to_be_a_miracle_(this_thing_called_love).txt"},
#     'Eagles': {'Outlaw Man': 'outlaw_man.txt'},
#     'Temptations': {'Girls (They Like It)': 'girls_(they_like_it).txt'}}},
#   'When The River Runs Deep': {'file_name': 'when_the_river_runs_deep.txt',
#    'recommendations': {'James Brown': {"That'S When I Lost My Heart": "that's_when_i_lost_my_heart.txt"},
#     'Ray Charles': {'Little Hotel Room': 'little_hotel_room.txt'},
#     'Hank Williams': {'The Pale Horse And His Rider': 'the_pale_horse_and_his_rider.txt'},
#     'Pink Floyd': {'Not Now John': 'not_now_john.txt'}}},
#   'Prodigal Son': {'file_name': 'prodigal_son.txt',
#    'recommendations': {'Billy Joel': {'Piano Man': 'piano_man.txt'},
#     'Elton John': {'Something About The Way You Look Tonight': 'something_about_the_way_you_look_tonight.txt'},
#     'Slayer': {'In The Name Of God': 'in_the_name_of_god.txt'},
#     'Bruno Mars': {"That'S What I Like": "that's_what_i_like.txt"},
#     'Temptations': {'Everything For Christmas': 'everything_for_christmas.txt'}}},
#   'Ghost Of The Navigator': {'file_name': 'ghost_of_the_navigator.txt',
#    'recommendations': {'Iron Maiden': {'Gangland': 'gangland.txt'},
#     'Ashanti': {'Foolish': 'foolish.txt'},
#     'Slayer': {'Ddamm (Drunk Drivers Against Mad Mothers)': 'ddamm_(drunk_drivers_against_mad_mothers).txt'},
#     'Hank Williams': {"I Can'T Help It (If I'M Still In Love With You)": "i_can't_help_it_(if_i'm_still_in_love_with_you).txt"},
#     'Van Morrison': {'Full Force Gale': 'full_force_gale.txt'}}},
#   'Another Life': {'file_name': 'another_life.txt',
#    'recommendations': {'Hank Williams': {'(Last Night) I Heard You Crying In Your Sleep': '(last_night)_i_heard_you_crying_in_your_sleep.txt'},
#     'KISS': {'Murder In High-Heels': 'murder_in_high-heels.txt'},
#     'Roy Orbison': {'Crying': 'crying.txt'},
#     'Alicia Keys': {"If I Ain'T Got You": "if_i_ain't_got_you.txt"},
#     'Genesis': {'I Know What I Like (In Your Wardrobe)': 'i_know_what_i_like_(in_your_wardrobe).txt'}}},
#   'Twilight Zone': {'file_name': 'twilight_zone.txt',
#    'recommendations': {'Hank Williams': {"I'M Sorry For You, My Friend": "i'm_sorry_for_you,_my_friend.txt"},
#     'Willie Nelson': {'Wabash Cannonball': 'wabash_cannonball.txt'},
#     'Donna Summer': {'Bad Girls': 'bad_girls.txt'},
#     'Beatles': {'Iwanttoholdyourhand': 'iwanttoholdyourhand.txt'},
#     'Bo Diddley': {'Before You Accuse Me': 'before_you_accuse_me.txt'}}},
#   'Can I Play With Madness?': {'file_name': 'can_i_play_with_madness?.txt',
#    'recommendations': {'Amy Winehouse': {'Best Friends, Right?': 'best_friends,_right?.txt'},
#     'Ray Charles': {"I Can'T Stop Loving You": "i_can't_stop_loving_you.txt"},
#     'Sam Cooke': {'Canadian Sunset': 'canadian_sunset.txt'},
#     'James Brown': {'Tell Me What I Did Wrong': 'tell_me_what_i_did_wrong.txt'},
#     'Nickelback': {'How You Remind Me': 'how_you_remind_me.txt'}}}},
#  'Mariah Carey': {'Always Be My Baby': {'file_name': 'always_be_my_baby.txt',
#    'recommendations': {'Jay-Z': {'Face Off': 'face_off.txt'},
#     'Queen': {'Bohemian Rhapsody': 'bohemian_rhapsody.txt'},
#     'Diana Ross': {'Touch Me In The Morning': 'touch_me_in_the_morning.txt'},
#     'Four Seasons': {'December, 1963 (Oh, What A Night)': 'december,_1963_(oh,_what_a_night).txt'},
#     'Pearl Jam': {'Soon Forget': 'soon_forget.txt'}}},
#   'We Belong Together': {'file_name': 'we_belong_together.txt',
#    'recommendations': {'Foo Fighters': {'Miss The Misery': 'miss_the_misery.txt'},
#     'Hank Williams': {'Wedding Bells': 'wedding_bells.txt'},
#     'Police': {'Demolition Man': 'demolition_man.txt'},
#     'Hall & Oates': {'Thank You For...': 'thank_you_for....txt'},
#     'Captain & Tennille': {'Love Will Keep Us Together': 'love_will_keep_us_together.txt'}}},
#   'Hero': {'file_name': 'hero.txt',
#    'recommendations': {'Jerry Lee Lewis': {'Sticks And Stones': 'sticks_and_stones.txt'},
#     'Van Halen': {'Hear About It Later': 'hear_about_it_later.txt'},
#     'Run-DMC': {"Livin' In The City": "livin'_in_the_city.txt"},
#     'Aretha Franklin': {'The Weight': 'the_weight.txt'},
#     'Ray Charles': {'Candy': 'candy.txt'}}},
#   'One Sweet Day': {'file_name': 'one_sweet_day.txt',
#    'recommendations': {'Slayer': {'Vices': 'vices.txt'},
#     'Ray Charles': {"Sinner'S Prayer": "sinner's_prayer.txt"},
#     'Prince': {'New Power Generation (Pt. Ii)': 'new_power_generation_(pt._ii).txt'},
#     'Eurythmics': {'In This Town': 'in_this_town.txt'},
#     'Metallica': {'The House Jack Built': 'the_house_jack_built.txt'}}}},
#  'Bette Midler': {'The Rose': {'file_name': 'the_rose.txt',
#    'recommendations': {'Righteous Brothers': {'Hey, Girl': 'hey,_girl.txt'},
#     'Bob Marley': {'Midnight Ravers': 'midnight_ravers.txt'},
#     'Simon & Garfunkel': {'Save The Life Of My Child': 'save_the_life_of_my_child.txt'},
#     'Kraftwerk': {'Vitamin': 'vitamin.txt'},
#     'Rick Springfield': {"Jessie'S Girl": "jessie's_girl.txt"}}}},
#  'Emotions': {'Best Of My Love': {'file_name': 'best_of_my_love.txt',
#    'recommendations': {'Chuck Berry': {'I Do Really Love You': 'i_do_really_love_you.txt'},
#     'Genesis': {'I Know What I Like (In Your Wardrobe)': 'i_know_what_i_like_(in_your_wardrobe).txt'},
#     'Sex Pistols': {'I Wanna Be Me': 'i_wanna_be_me.txt'},
#     'Little Richard': {'Only You': 'only_you.txt'},
#     'Bo Diddley': {'Lodi': 'lodi.txt'}}}},
#  'Nelly Furtado': {'Promiscuous': {'file_name': 'promiscuous.txt',
#    'recommendations': {'Santana': {'Daughter Of The Night': 'daughter_of_the_night.txt'},
#     'Lady Gaga': {'Poker Face': 'poker_face.txt'},
#     'Everly Brothers': {'Love Is Strange': 'love_is_strange.txt'},
#     'Smokey Robinson & The Miracles': {"I'Ve Got You Under My Skin": "i've_got_you_under_my_skin.txt"},
#     'Kool & the Gang': {'Celebration': 'celebration.txt'}}}},
#  'Police': {'Next To You': {'file_name': 'next_to_you.txt',
#    'recommendations': {'Police': {'Tea In The Sahara': 'tea_in_the_sahara.txt'},
#     'Iron Maiden': {'Judgement Day': 'judgement_day.txt'},
#     'Clash': {'Death Is A Star': 'death_is_a_star.txt'},
#     'James Brown': {'Bewildered': 'bewildered.txt'},
#     'Hank Williams': {"I'M Satisfied With You": "i'm_satisfied_with_you.txt"}}},
#   'Walking On The Moon': {'file_name': 'walking_on_the_moon.txt',
#    'recommendations': {'Ray Charles': {"Dream (When You'Re Feeling Blue)": "dream_(when_you're_feeling_blue).txt"},
#     'Public Enemy': {'Get Up Stand Up': 'get_up_stand_up.txt'},
#     'Willie Nelson': {'Good Times': 'good_times.txt'},
#     'Police': {"When The World Is Running Down, You Make The Best Of What'S Still Around": "when_the_world_is_running_down,_you_make_the_best_of_what's_still_around.txt"},
#     'Queen': {'The Night Comes Down': 'the_night_comes_down.txt'}}},
#   'Every Breath You Take': {'file_name': 'every_breath_you_take.txt',
#    'recommendations': {'Judas Priest': {'Freewheel Burning': 'freewheel_burning.txt'},
#     'Beatles': {'She Loves You': 'she_loves_you.txt'},
#     'Foo Fighters': {'Danny Says(Special Limited Edition Bonus Track)': 'danny_says(special_limited_edition_bonus_track).txt'},
#     'Smokey Robinson & The Miracles': {'Broken Hearted': 'broken_hearted.txt'},
#     'Hall & Oates': {'Fall In Philadelphia': 'fall_in_philadelphia.txt'}}},
#   'Omegaman': {'file_name': 'omegaman.txt',
#    'recommendations': {'REM': {"You'Re In The Air": "you're_in_the_air.txt"},
#     'Ray Charles': {'Cherry': 'cherry.txt'},
#     'Willie Nelson': {"You'Ll Never Know": "you'll_never_know.txt"},
#     'Smokey Robinson & The Miracles': {'Come On Do The Jerk': 'come_on_do_the_jerk.txt'},
#     'Judas Priest': {'Screaming For Vengeance': 'screaming_for_vengeance.txt'}}},
#   "It'S Alright For You": {'file_name': "it's_alright_for_you.txt",
#    'recommendations': {'Def Leppard': {'Wasted': 'wasted.txt'},
#     'Santana': {'Let There Be Light': 'let_there_be_light.txt'},
#     'Grand Funk Railroad': {'The Loco-Motion': 'the_loco-motion.txt'},
#     'Ray Charles': {'Two Ton Tessie': 'two_ton_tessie.txt'},
#     'Jerry Lee Lewis': {'Green Green Grass Of Home': 'green_green_grass_of_home.txt'}}},
#   'Tea In The Sahara': {'file_name': 'tea_in_the_sahara.txt',
#    'recommendations': {'Santana': {'Day Of Celebration': 'day_of_celebration.txt'},
#     'Little Richard': {'Kansas City': 'kansas_city.txt'},
#     'Bo Diddley': {'Down On The Corner': 'down_on_the_corner.txt'},
#     'Aerosmith': {'Beyond Beautiful': 'beyond_beautiful.txt'},
#     'Chuck Berry': {'Route 66': 'route_66.txt'}}},
#   'Hole In My Life': {'file_name': 'hole_in_my_life.txt',
#    'recommendations': {'Ray Charles': {'Greenbacks': 'greenbacks.txt'},
#     'Willie Nelson': {'Happiness Lives Next Door': 'happiness_lives_next_door.txt'},
#     'Billy Joel': {"No Man'S Land": "no_man's_land.txt"},
#     'Radiohead': {'Fog': 'fog.txt'}}},
#   'Synchronicity Ii': {'file_name': 'synchronicity_ii.txt',
#    'recommendations': {'Clash': {'The Equaliser': 'the_equaliser.txt'},
#     'Ray Charles': {"Alexander'S Ragtime Band": "alexander's_ragtime_band.txt"},
#     'Bobby Brown': {'My Prerogative': 'my_prerogative.txt'},
#     'James Brown': {"I Can'T Stand Myself (When You Touch Me), Pt. 1": "i_can't_stand_myself_(when_you_touch_me),_pt._1.txt"},
#     'Everly Brothers': {'She Never Smiles Anymore': 'she_never_smiles_anymore.txt'}}},
#   'So Lonely': {'file_name': 'so_lonely.txt',
#    'recommendations': {'George Michael': {'Careless Whisper': 'careless_whisper.txt'},
#     'Temptations': {'Girls (They Like It)': 'girls_(they_like_it).txt'},
#     'Ray Charles': {'Falling In Love With Love': 'falling_in_love_with_love.txt'},
#     'Metallica': {'The Small Hours': 'the_small_hours.txt'},
#     'Clash': {'Janie Jones': 'janie_jones.txt'}}},
#   'Demolition Man': {'file_name': 'demolition_man.txt',
#    'recommendations': {'Clash': {'Cheat': 'cheat.txt'},
#     'Michael Jackson': {'Billie Jean': 'billie_jean.txt'},
#     'Willie Nelson': {'Homeward Bound': 'homeward_bound.txt'},
#     'Next': {'Too Close': 'too_close.txt'},
#     'Ray Charles': {'Willow, Weep For Me': 'willow,_weep_for_me.txt'}}},
#   "When The World Is Running Down, You Make The Best Of What'S Still Around": {'file_name': "when_the_world_is_running_down,_you_make_the_best_of_what's_still_around.txt",
#    'recommendations': {'Jimi Hendrix': {'Drifting': 'drifting.txt'},
#     'Beatles': {'You Like Me Too Much': 'you_like_me_too_much.txt'},
#     'Bo Diddley': {'Nursery Rhyme': 'nursery_rhyme.txt'},
#     'Ray Charles': {"Don'T Let The Sun Catch You Cryin'": "don't_let_the_sun_catch_you_cryin'.txt"}}},
#   'Landlord': {'file_name': 'landlord.txt',
#    'recommendations': {'Temptations': {"Don'T Let Him Take Your Love From Me": "don't_let_him_take_your_love_from_me.txt"},
#     'Beach Boys': {'The Girl From New York City': 'the_girl_from_new_york_city.txt'},
#     'Brenda Lee': {"I'M Sorry": "i'm_sorry.txt"},
#     'Smokey Robinson & The Miracles': {'Save Me': 'save_me.txt'},
#     'Beatles': {'You Like Me Too Much': 'you_like_me_too_much.txt'}}},
#   'Once Upon A Daydream(B-Side)': {'file_name': 'once_upon_a_daydream(b-side).txt',
#    'recommendations': {'Foo Fighters': {'Podunk(Japanese Bonus Track)': 'podunk(japanese_bonus_track).txt'},
#     'Herb Alpert': {"This Guy'S In Love With You": "this_guy's_in_love_with_you.txt"},
#     'Rick Astley': {'Never Gonna Give You Up': 'never_gonna_give_you_up.txt'},
#     'Frank Sinatra': {'Paradise': 'paradise.txt'},
#     'Santana': {'Smooth': 'smooth.txt'}}},
#   'Roxanne': {'file_name': 'roxanne.txt',
#    'recommendations': {'Color Me Badd': {'I Wanna Sex You Up': 'i_wanna_sex_you_up.txt'},
#     'Beach Boys': {'How She Boogalooed It': 'how_she_boogalooed_it.txt'},
#     'Ray Charles': {'Crazy Old Soldier': 'crazy_old_soldier.txt'},
#     'Jerry Lee Lewis': {"Big Blon' Baby": "big_blon'_baby.txt"},
#     'James Brown': {"I'Ll Go Crazy": "i'll_go_crazy.txt"}}},
#   'Every Little Thing She Does Is Magic': {'file_name': 'every_little_thing_she_does_is_magic.txt',
#    'recommendations': {'Bo Diddley': {'Who May Your Lover Be': 'who_may_your_lover_be.txt'},
#     'Aretha Franklin': {'Baby, Baby, Baby': 'baby,_baby,_baby.txt'},
#     'Santana': {'Smooth': 'smooth.txt'},
#     'Police': {'Visions Of The Night(From "Walking On The Moon" Single)': 'visions_of_the_night(from_"walking_on_the_moon"_single).txt'}}},
#   'Visions Of The Night(From "Walking On The Moon" Single)': {'file_name': 'visions_of_the_night(from_"walking_on_the_moon"_single).txt',
#    'recommendations': {'Frank Sinatra': {"I Don'T Know Why (I Just Do)": "i_don't_know_why_(i_just_do).txt"},
#     'ACDC': {'Hard Times': 'hard_times.txt'},
#     'Ray Charles': {'Crazy Old Soldier': 'crazy_old_soldier.txt'},
#     'Santana': {'Smooth': 'smooth.txt'}}},
#   'Be My Girl - Sally': {'file_name': 'be_my_girl_-_sally.txt',
#    'recommendations': {'Little Richard': {'Kansas City': 'kansas_city.txt'},
#     'Willie Nelson': {'Take It To The Limit': 'take_it_to_the_limit.txt'},
#     'Ray Charles': {'Marie': 'marie.txt'},
#     'Metallica': {'Cheat On Me': 'cheat_on_me.txt'},
#     'Supremes': {'Your Heart Belongs To Me': 'your_heart_belongs_to_me.txt'}}}}}

# %%
# chars = '*" / \ [ ] : ; | ,'

artists = os.listdir('lyrics')
# for char in chars:
for artist in artists:
    songs = os.listdir(f'lyrics/{artist}')
    for song in songs:
        os.rename(f'lyrics/{artist}/{song}', f"lyrics/{artist}/{song.replace('txt', '.txt')}")
